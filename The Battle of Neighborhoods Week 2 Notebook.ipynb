# %% [markdown]
# # Capstone Project: The Battle of Neighborhoods (Week 2)

# %% [markdown]
# ## Table Of Contents
# * [An Introdunction To The Business Problem](#introduction)
# * [A Description Of The Data To Be Used](#data)
# * [Methodology](#methodology)
# * [Analysis](#analysis)
# * [Results](#results)
# * [Discussion](#discussion)
# * [Conclusion](#conclusion)

# %% [markdown]
# ## An Introdunction To The Business Problem <a name="introduction"></a>
#
# The United States Tennis Association (USTA) is planning to organize a number of Tennis tournaments, coaching courses, seminars and workshops for professional tennis players and coaches from all over the world during the next few months. All the events mentioned above are scheduled to take place in The National Tennis Developement Center located in Flushing Meadows, New York. Most of the players and coaches participating in any event will require lodging and dining facilities throughout the duration of the event. Additionally, the management of USTA has decided that a gymming facility shall also be made available to the participants. But, the venue does not have any facilities for the lodging, dining or gymming of the participants. So, after a number of meetings, the management has decided to collaborate with a few Hotels, Restaurants and Gyms within a specified radius from the academy in order to provide the participants with the required facilities. The Data Science Department of the USTA has been tasked with fulfilling the following objectives:
#
#    1. Identify 8 Hotels that are nearest to the academy within a 1.5 KM radius.
#    2. Identify 8 Restaurants that are nearest to the academy within a 500 meter radius.
#    3. Identify 3 Gyms that are nearest to the academy within a 3 KM radius.
#    4. Visualize the locations identified on one single map.
#
# There is a requirement for 5 Hotels, 5 Restaurants and 2 Gyms. So, the locations identified by the Data Science Department will be scrutinized and explored further by the management for the selection of suitable Hotels, Restaurants and Gyms to collaborate with.

# %% [markdown]
# ## A Description Of The Data To Be Used <a name="data"></a>
#
# The data used in this project will be based on Foursquare location data for Flushing, NY 11368, United States. This data will help in solving the business problem highlighted previously. Using Foursquare location data, it will be possible to explore all the Hotels, Restaurants and Gyms within the specified radius of the venue. Data related to the locations of interest will be extracted using Foursquare and it will be used to produce DataFrames. The data to be used in producing the DataFrames is as follows:
#
#    1. Name of the location of interest.
#    2. Category of the location of interest.
#    3. Address of the location of interest.
#    4. Distance of the location of interest from the venue.
#    5. Latitude of the location of interest.
#    6. Longitude of the location of interest.
#    7. Postal Code of the location of interest.

# %% [markdown]
# ## Methodology <a name="methodology"></a>

# %% [markdown]
# In this project, the efforts will be directed on identifying the three types of locations highlighted in the Introduction Section, namely, Hotels, Restaurants and Gyms. In particular, those locations will be selected that are within the specified radius of the venue where the events are scheduled to take place.
#
# 1. As the first step, all the necessary libraries for obtaining the data, it's exploration, analysis and visualization will be imported.
#
# 2. The second step will be to define the Foursquare credentials.
#
# 3. As the third step, the coordinates of the venue will be obtained.
#
# 4. Next, the following steps will be performed for each of the three locations of interest (Hotels, Restaurants and Gyms):
#
#    - A URL for the Foursquare API will be defined.
#    - The data related to the location of interest will be obtained using the Foursquare API in JSON format.
#    - The relevant part of the JSON object will be converted into a DataFrame
#    - The DataFrame will be cleaned and all the rows containing NaN or Null values will be dropped. Additionally, all the useless columns will also be dropped.
#    - The rows of the DataFrame will be sorted in ascending order of the 'distance' column and the required number of rows will be selected from the top.
#
#
# 5. In the final step, the data in the DataFrames will be used to visualize the locations on a map centered around the venue. This will be done using the Folium library.

# %% [markdown]
# ## Importing Necessary Libraries

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

#!conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

#!conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# ## Defining Foursquare Credentials

# %%
CLIENT_ID = 'CX52FPGWLTFOMA4TJ3KTCYNK1OXFLEWYLJ4MMZUS0ZMHSPDU' # Foursquare ID
CLIENT_SECRET = 'ACRWE2VD5G45WE5HJISORFKFJJ0DOBBVV3ZF4RGLA3HBXTB4' # Foursquare Secret
VERSION = '20180604'
LIMIT = 30

# %% [markdown]
# ## Obtaining The Coordinates Of The Venue

# %%
address = 'Flushing, NY 11368, United States'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 40.7654301 -73.8174291

# %% [markdown]
# ## Analysis <a name="analysis"></a>

# %% [markdown]
# ### Searching For Hotels Within A 1.5 KM Radius

# %%
# Search for hotels within a radius of 1.5 Kilometeres
search_query = 'Hotel'
radius = 1500

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=CX52FPGWLTFOMA4TJ3KTCYNK1OXFLEWYLJ4MMZUS0ZMHSPDU&client_secret=ACRWE2VD5G45WE5HJISORFKFJJ0DOBBVV3ZF4RGLA3HBXTB4&ll=40.7654301,-73.8174291&v=20180604&query=Hotel&radius=1500&limit=30'

# %% [markdown]
# ### Sending The GET Request And Examining The Results

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5df4fc31e826ac001b6cc15f'},
#  'response': {'venues': [{'id': '4af973f4f964a520d91122e3',
#     'name': 'Sheraton LaGuardia East Hotel',
#     'location': {'address': '135-20 39th Ave',
#      'crossStreet': 'Prince St',
#      'lat': 40.759726,
#      'lng': -73.8316771,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.759726,
#        'lng': -73.8316771}],
#      'distance': 1358,
#      'postalCode': '11354',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['135-20 39th Ave (Prince St)',
#       'Flushing, NY 11354',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336505',
#     'hasPerk': False},
#    {'id': '4bb2532b35f0c9b6721fbb83',
#     'name': 'Marco LaGuardia Hotel by Lexington',
#     'location': {'address': '137-07 Northern Blvd',
#      'lat': 40.76356716962587,
#      'lng': -73.83104794108021,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76356716962587,
#        'lng': -73.83104794108021}],
#      'distance': 1166,
#      'postalCode': '11354',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['137-07 Northern Blvd',
#       'Flushing, NY 11354',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336505',
#     'hasPerk': False},
#    {'id': '57ff3a3a498ebca33b7bc7ba',
#     'name': 'Sheraton Laguardia East Hotel',
#     'location': {'lat': 40.76538,
#      'lng': -73.81736,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76538,
#        'lng': -73.81736}],
#      'distance': 8,
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Flushing, NY', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e5931735',
#       'name': 'Music Venue',
#       'pluralName': 'Music Venues',
#       'shortName': 'Music Venue',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336505',
#     'hasPerk': False},
#    {'id': '59677595b37e2b3e8787d9a5',
#     'name': 'John Hotel In Flushing',
#     'location': {'address': '13312 37th Ave',
#      'lat': 40.760193,
#      'lng': -73.834361,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.760193,
#        'lng': -73.834361}],
#      'distance': 1542,
#      'postalCode': '11354',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['13312 37th Ave',
#       'Flushing, NY 11354',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336505',
#     'hasPerk': False},
#    {'id': '522732b611d232d9f01b8651',
#     'name': 'The One Boutique Hotel',
#     'location': {'address': '137-37 Northern Blvd',
#      'crossStreet': 'Union Avenue',
#      'lat': 40.76374294055137,
#      'lng': -73.8285238457772,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76374294055137,
#        'lng': -73.8285238457772}],
#      'distance': 954,
#      'postalCode': '11358',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['137-37 Northern Blvd (Union Avenue)',
#       'Flushing, NY 11358',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d12f951735',
#       'name': 'Resort',
#       'pluralName': 'Resorts',
#       'shortName': 'Resort',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/resort_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336505',
#     'hasPerk': False},
#    {'id': '4f11ff3ce4b04720455ff9a1',
#     'name': 'Hotel Aramie',
#     'location': {'lat': 40.75700796987974,
#      'lng': -73.8109273886549,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75700796987974,
#        'lng': -73.8109273886549}],
#      'distance': 1086,
#      'postalCode': '11355',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Flushing, NY 11355', 'United States']},
#     'categories': [],
#     'referralId': 'v-1576336505',
#     'hasPerk': False},
#    {'id': '50901edfe4b0ae9e17973984',
#     'name': 'Asiatic Hotel',
#     'location': {'address': '135-21 37th Ave',
#      'crossStreet': 'Between Prince St. & Main St.',
#      'lat': 40.76110892593731,
#      'lng': -73.83233707055915,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76110892593731,
#        'lng': -73.83233707055915}],
#      'distance': 1345,
#      'postalCode': '11354',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['135-21 37th Ave (Between Prince St. & Main St.)',
#       'Flushing, NY 11354',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336505',
#     'hasPerk': False},
#    {'id': '4bc36331dce4eee15194719d',
#     'name': 'Flushing Grand Hotel',
#     'location': {'address': '3638 Main St',
#      'lat': 40.7621239402231,
#      'lng': -73.8319156058555,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7621239402231,
#        'lng': -73.8319156058555}],
#      'distance': 1275,
#      'postalCode': '11354',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['3638 Main St',
#       'Flushing, NY 11354',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336505',
#     'hasPerk': False},
#    {'id': '5bab15af3b8307002cc005ef',
#     'name': 'Hotel Indigo Flushing',
#     'location': {'address': '35-57 Prince Street',
#      'lat': 40.76242971948355,
#      'lng': -73.83284242401447,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76242971948355,
#        'lng': -73.83284242401447}],
#      'distance': 1341,
#      'postalCode': '11354',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['35-57 Prince Street',
#       'Flushing, NY 11354',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336505',
#     'hasPerk': False},
#    {'id': '578dec46498ef6de24c32a8a',
#     'name': 'Grandview Hotel New York',
#     'location': {'address': '31-16 Linden Pl',
#      'lat': 40.768807,
#      'lng': -73.832703,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.768807,
#        'lng': -73.832703}],
#      'distance': 1341,
#      'postalCode': '11354',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['31-16 Linden Pl',
#       'New York, NY 11354',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336505',
#     'hasPerk': False},
#    {'id': '4bc3758ddce4eee13f9d719d',
#     'name': 'Best Western Queens Court Hotel',
#     'location': {'address': '13351 39th Ave',
#      'crossStreet': 'at Prince St',
#      'lat': 40.75977314242092,
#      'lng': -73.83288595904463,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75977314242092,
#        'lng': -73.83288595904463}],
#      'distance': 1447,
#      'postalCode': '11354',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['13351 39th Ave (at Prince St)',
#       'Flushing, NY 11354',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336505',
#     'hasPerk': False},
#    {'id': '4e6c41e752b1456286475c7f',
#     'name': 'Jinfeng Hotel',
#     'location': {'address': '143-49 Ash Ave',
#      'lat': 40.757871,
#      'lng': -73.8204,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.757871,
#        'lng': -73.8204}],
#      'distance': 877,
#      'postalCode': '11355',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['143-49 Ash Ave',
#       'Flushing, NY 11355',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336505',
#     'hasPerk': False},
#    {'id': '5c422f423abcaf002cc88f5e',
#     'name': 'The Restaurant at Sheraton LaGuardia East Hotel',
#     'location': {'address': '135-20 39th Ave',
#      'lat': 40.7602769454966,
#      'lng': -73.83032441139221,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7602769454966,
#        'lng': -73.83032441139221}],
#      'distance': 1229,
#      'postalCode': '11354',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['135-20 39th Ave',
#       'Flushing, NY 11354',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336505',
#     'hasPerk': False},
#    {'id': '5019c013e4b031d2e457565e',
#     'name': 'Farrington Hotel',
#     'location': {'lat': 40.76556032048273,
#      'lng': -73.83160545135695,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76556032048273,
#        'lng': -73.83160545135695}],
#      'distance': 1195,
#      'cc': 'US',
#      'state': 'New York',
#      'country': 'United States',
#      'formattedAddress': ['New York', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fb931735',
#       'name': 'Motel',
#       'pluralName': 'Motels',
#       'shortName': 'Motel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336505',
#     'hasPerk': False},
#    {'id': '4ee8d8c0e5fadaeb5e387b1c',
#     'name': 'Navaratna Hotel In CBD',
#     'location': {'lat': 40.756033,
#      'lng': -73.825229,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.756033,
#        'lng': -73.825229}],
#      'distance': 1235,
#      'postalCode': '11355',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Flushing, NY 11355', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336505',
#     'hasPerk': False},
#    {'id': '4ee8d94b8231d71b3a3cf6b1',
#     'name': 'Navaratna Hotel',
#     'location': {'lat': 40.756033,
#      'lng': -73.825229,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.756033,
#        'lng': -73.825229}],
#      'distance': 1235,
#      'postalCode': '11355',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Flushing, NY 11355', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336505',
#     'hasPerk': False},
#    {'id': '5171dee2498e3b9ba304c580',
#     'name': 'Sheraton Hotel Flushing',
#     'location': {'lat': 40.757730492600885,
#      'lng': -73.8292850207842,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.757730492600885,
#        'lng': -73.8292850207842}],
#      'distance': 1316,
#      'cc': 'US',
#      'city': 'Queens',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Queens, NY', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336505',
#     'hasPerk': False},
#    {'id': '4d15a25c1356a093ab86d182',
#     'name': 'Flushing International Hotel',
#     'location': {'address': '35th Ave',
#      'lat': 40.76432030217045,
#      'lng': -73.83200750339125,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76432030217045,
#        'lng': -73.83200750339125}],
#      'distance': 1235,
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['35th Ave', 'Flushing, NY', 'United States']},
#     'categories': [],
#     'referralId': 'v-1576336505',
#     'hasPerk': False},
#    {'id': '5a1a0b2365cdf8781c27d74f',
#     'name': 'Flushing Central Hotel',
#     'location': {'address': '135-33 38th Ave',
#      'lat': 40.760684,
#      'lng': -73.831432,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.760684,
#        'lng': -73.831432}],
#      'distance': 1293,
#      'postalCode': '11354',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['135-33 38th Ave',
#       'Flushing, NY 11354',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336505',
#     'hasPerk': False},
#    {'id': '518ebb49498e836c4983b20f',
#     'name': 'Sheraton LaGuardia East Hotel Garnet Room',
#     'location': {'address': '135-20 39th Ave',
#      'crossStreet': 'Prince St',
#      'lat': 40.762277545594664,
#      'lng': -73.83241529819077,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.762277545594664,
#        'lng': -73.83241529819077}],
#      'distance': 1311,
#      'postalCode': '11354',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['135-20 39th Ave (Prince St)',
#       'Flushing, NY 11354',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d171941735',
#       'name': 'Event Space',
#       'pluralName': 'Event Spaces',
#       'shortName': 'Event Space',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/eventspace_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336505',
#     'hasPerk': False},
#    {'id': '4d2fbf987791224b2ae2ca42',
#     'name': 'Double tree hotel',
#     'location': {'lat': 40.753359270995965,
#      'lng': -73.82803131923687,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.753359270995965,
#        'lng': -73.82803131923687}],
#      'distance': 1613,
#      'cc': 'US',
#      'state': 'New York',
#      'country': 'United States',
#      'formattedAddress': ['New York', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336505',
#     'hasPerk': False},
#    {'id': '50c200dbe4b0e64f1d3279c1',
#     'name': 'Bajwa Hotels',
#     'location': {'lat': 40.758244,
#      'lng': -73.807939,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.758244,
#        'lng': -73.807939}],
#      'distance': 1131,
#      'postalCode': '11358',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Flushing, NY 11358', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336505',
#     'hasPerk': False}]}}

# %% [markdown]
# ### Assigning Relevant Part Of The JSON To Venues And Transforming The Venues Into A DataFrame

# %%
venues = results['response']['venues']

dataframe_hotel = json_normalize(venues)
dataframe_hotel.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 1  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 2  [{'id': '4bf58dd8d48988d1e5931735', 'name': 'M...    False
# 3  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 4  [{'id': '4bf58dd8d48988d12f951735', 'name': 'R...    False
#
#                          id      location.address location.cc location.city  \
# 0  4af973f4f964a520d91122e3       135-20 39th Ave          US      Flushing
# 1  4bb2532b35f0c9b6721fbb83  137-07 Northern Blvd          US      Flushing
# 2  57ff3a3a498ebca33b7bc7ba                   NaN          US      Flushing
# 3  59677595b37e2b3e8787d9a5        13312 37th Ave          US      Flushing
# 4  522732b611d232d9f01b8651  137-37 Northern Blvd          US      Flushing
#
#   location.country location.crossStreet  location.distance  \
# 0    United States            Prince St               1358
# 1    United States                  NaN               1166
# 2    United States                  NaN                  8
# 3    United States                  NaN               1542
# 4    United States         Union Avenue                954
#
#                            location.formattedAddress  \
# 0  [135-20 39th Ave (Prince St), Flushing, NY 113...
# 1  [137-07 Northern Blvd, Flushing, NY 11354, Uni...
# 2                      [Flushing, NY, United States]
# 3  [13312 37th Ave, Flushing, NY 11354, United St...
# 4  [137-37 Northern Blvd (Union Avenue), Flushing...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 40.759726, 'lng':...     40.759726
# 1  [{'label': 'display', 'lat': 40.76356716962587...     40.763567
# 2  [{'label': 'display', 'lat': 40.76538, 'lng': ...     40.765380
# 3  [{'label': 'display', 'lat': 40.760193, 'lng':...     40.760193
# 4  [{'label': 'display', 'lat': 40.76374294055137...     40.763743
#
#    location.lng location.postalCode location.state  \
# 0    -73.831677               11354             NY
# 1    -73.831048               11354             NY
# 2    -73.817360                 NaN             NY
# 3    -73.834361               11354             NY
# 4    -73.828524               11358             NY
#
#                                  name    referralId
# 0       Sheraton LaGuardia East Hotel  v-1576336505
# 1  Marco LaGuardia Hotel by Lexington  v-1576336505
# 2       Sheraton Laguardia East Hotel  v-1576336505
# 3              John Hotel In Flushing  v-1576336505
# 4              The One Boutique Hotel  v-1576336505

# %% [markdown]
# ### Cleaning The DataFrame

# %%
# Keep only columns that include venue name, and anything that is associated with location
new_columns = ['name', 'categories'] + [col for col in dataframe_hotel.columns if col.startswith('location.')]+ ['id']
new_dataframe_hotel = dataframe_hotel.loc[:, new_columns]

# Function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# Filter the category for each row
new_dataframe_hotel['categories'] = new_dataframe_hotel.apply(get_category_type, axis=1)

# Clean column names by keeping only last term
new_dataframe_hotel.columns = [column.split('.')[-1] for column in new_dataframe_hotel.columns]

new_dataframe_hotel.head()
# Out:
#                                  name   categories               address  cc  \
# 0       Sheraton LaGuardia East Hotel        Hotel       135-20 39th Ave  US
# 1  Marco LaGuardia Hotel by Lexington        Hotel  137-07 Northern Blvd  US
# 2       Sheraton Laguardia East Hotel  Music Venue                   NaN  US
# 3              John Hotel In Flushing        Hotel        13312 37th Ave  US
# 4              The One Boutique Hotel       Resort  137-37 Northern Blvd  US
#
#        city        country   crossStreet  distance  \
# 0  Flushing  United States     Prince St      1358
# 1  Flushing  United States           NaN      1166
# 2  Flushing  United States           NaN         8
# 3  Flushing  United States           NaN      1542
# 4  Flushing  United States  Union Avenue       954
#
#                                     formattedAddress  \
# 0  [135-20 39th Ave (Prince St), Flushing, NY 113...
# 1  [137-07 Northern Blvd, Flushing, NY 11354, Uni...
# 2                      [Flushing, NY, United States]
# 3  [13312 37th Ave, Flushing, NY 11354, United St...
# 4  [137-37 Northern Blvd (Union Avenue), Flushing...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 40.759726, 'lng':...  40.759726 -73.831677
# 1  [{'label': 'display', 'lat': 40.76356716962587...  40.763567 -73.831048
# 2  [{'label': 'display', 'lat': 40.76538, 'lng': ...  40.765380 -73.817360
# 3  [{'label': 'display', 'lat': 40.760193, 'lng':...  40.760193 -73.834361
# 4  [{'label': 'display', 'lat': 40.76374294055137...  40.763743 -73.828524
#
#   postalCode state                        id
# 0      11354    NY  4af973f4f964a520d91122e3
# 1      11354    NY  4bb2532b35f0c9b6721fbb83
# 2        NaN    NY  57ff3a3a498ebca33b7bc7ba
# 3      11354    NY  59677595b37e2b3e8787d9a5
# 4      11358    NY  522732b611d232d9f01b8651

# %% [markdown]
# ### Dropping Useless Columns

# %%
new_dataframe_hotel2 = new_dataframe_hotel.drop(['cc', 'city', 'country', 'crossStreet', 'formattedAddress', 'labeledLatLngs', 'id', 'state'], axis=1)
new_dataframe_hotel2
# Out:
#                                                name         categories  \
# 0                     Sheraton LaGuardia East Hotel              Hotel
# 1                Marco LaGuardia Hotel by Lexington              Hotel
# 2                     Sheraton Laguardia East Hotel        Music Venue
# 3                            John Hotel In Flushing              Hotel
# 4                            The One Boutique Hotel             Resort
# 5                                      Hotel Aramie               None
# 6                                     Asiatic Hotel              Hotel
# 7                              Flushing Grand Hotel              Hotel
# 8                             Hotel Indigo Flushing              Hotel
# 9                          Grandview Hotel New York              Hotel
# 10                  Best Western Queens Court Hotel              Hotel
# 11                                    Jinfeng Hotel              Hotel
# 12  The Restaurant at Sheraton LaGuardia East Hotel   Asian Restaurant
# 13                                 Farrington Hotel              Motel
# 14                           Navaratna Hotel In CBD  Indian Restaurant
# 15                                  Navaratna Hotel  Indian Restaurant
# 16                          Sheraton Hotel Flushing           Building
# 17                     Flushing International Hotel               None
# 18                           Flushing Central Hotel              Hotel
# 19        Sheraton LaGuardia East Hotel Garnet Room        Event Space
# 20                                Double tree hotel              Hotel
# 21                                     Bajwa Hotels              Hotel
#
#                  address  distance        lat        lng postalCode
# 0        135-20 39th Ave      1358  40.759726 -73.831677      11354
# 1   137-07 Northern Blvd      1166  40.763567 -73.831048      11354
# 2                    NaN         8  40.765380 -73.817360        NaN
# 3         13312 37th Ave      1542  40.760193 -73.834361      11354
# 4   137-37 Northern Blvd       954  40.763743 -73.828524      11358
# 5                    NaN      1086  40.757008 -73.810927      11355
# 6        135-21 37th Ave      1345  40.761109 -73.832337      11354
# 7           3638 Main St      1275  40.762124 -73.831916      11354
# 8    35-57 Prince Street      1341  40.762430 -73.832842      11354
# 9        31-16 Linden Pl      1341  40.768807 -73.832703      11354
# 10        13351 39th Ave      1447  40.759773 -73.832886      11354
# 11        143-49 Ash Ave       877  40.757871 -73.820400      11355
# 12       135-20 39th Ave      1229  40.760277 -73.830324      11354
# 13                   NaN      1195  40.765560 -73.831605        NaN
# 14                   NaN      1235  40.756033 -73.825229      11355
# 15                   NaN      1235  40.756033 -73.825229      11355
# 16                   NaN      1316  40.757730 -73.829285        NaN
# 17              35th Ave      1235  40.764320 -73.832008        NaN
# 18       135-33 38th Ave      1293  40.760684 -73.831432      11354
# 19       135-20 39th Ave      1311  40.762278 -73.832415      11354
# 20                   NaN      1613  40.753359 -73.828031        NaN
# 21                   NaN      1131  40.758244 -73.807939      11358

# %% [markdown]
# ### Deleting Rows With NaN or Null Values

# %%
new_dataframe_hotel3 = new_dataframe_hotel2.dropna(axis=0)
new_dataframe_hotel3
# Out:
#                                                name        categories  \
# 0                     Sheraton LaGuardia East Hotel             Hotel
# 1                Marco LaGuardia Hotel by Lexington             Hotel
# 3                            John Hotel In Flushing             Hotel
# 4                            The One Boutique Hotel            Resort
# 6                                     Asiatic Hotel             Hotel
# 7                              Flushing Grand Hotel             Hotel
# 8                             Hotel Indigo Flushing             Hotel
# 9                          Grandview Hotel New York             Hotel
# 10                  Best Western Queens Court Hotel             Hotel
# 11                                    Jinfeng Hotel             Hotel
# 12  The Restaurant at Sheraton LaGuardia East Hotel  Asian Restaurant
# 18                           Flushing Central Hotel             Hotel
# 19        Sheraton LaGuardia East Hotel Garnet Room       Event Space
#
#                  address  distance        lat        lng postalCode
# 0        135-20 39th Ave      1358  40.759726 -73.831677      11354
# 1   137-07 Northern Blvd      1166  40.763567 -73.831048      11354
# 3         13312 37th Ave      1542  40.760193 -73.834361      11354
# 4   137-37 Northern Blvd       954  40.763743 -73.828524      11358
# 6        135-21 37th Ave      1345  40.761109 -73.832337      11354
# 7           3638 Main St      1275  40.762124 -73.831916      11354
# 8    35-57 Prince Street      1341  40.762430 -73.832842      11354
# 9        31-16 Linden Pl      1341  40.768807 -73.832703      11354
# 10        13351 39th Ave      1447  40.759773 -73.832886      11354
# 11        143-49 Ash Ave       877  40.757871 -73.820400      11355
# 12       135-20 39th Ave      1229  40.760277 -73.830324      11354
# 18       135-33 38th Ave      1293  40.760684 -73.831432      11354
# 19       135-20 39th Ave      1311  40.762278 -73.832415      11354

# %% [markdown]
# ### Deleting Rows Where Category Is Not Hotel

# %%
hotel_dataframe= new_dataframe_hotel3.loc[new_dataframe_hotel3['categories'] == 'Hotel']
hotel_dataframe
# Out:
#                                   name categories               address  \
# 0        Sheraton LaGuardia East Hotel      Hotel       135-20 39th Ave
# 1   Marco LaGuardia Hotel by Lexington      Hotel  137-07 Northern Blvd
# 3               John Hotel In Flushing      Hotel        13312 37th Ave
# 6                        Asiatic Hotel      Hotel       135-21 37th Ave
# 7                 Flushing Grand Hotel      Hotel          3638 Main St
# 8                Hotel Indigo Flushing      Hotel   35-57 Prince Street
# 9             Grandview Hotel New York      Hotel       31-16 Linden Pl
# 10     Best Western Queens Court Hotel      Hotel        13351 39th Ave
# 11                       Jinfeng Hotel      Hotel        143-49 Ash Ave
# 18              Flushing Central Hotel      Hotel       135-33 38th Ave
#
#     distance        lat        lng postalCode
# 0       1358  40.759726 -73.831677      11354
# 1       1166  40.763567 -73.831048      11354
# 3       1542  40.760193 -73.834361      11354
# 6       1345  40.761109 -73.832337      11354
# 7       1275  40.762124 -73.831916      11354
# 8       1341  40.762430 -73.832842      11354
# 9       1341  40.768807 -73.832703      11354
# 10      1447  40.759773 -73.832886      11354
# 11       877  40.757871 -73.820400      11355
# 18      1293  40.760684 -73.831432      11354

# %% [markdown]
# ### Sorting According To The Distance From The Academy And Selecting The Nearest Eight Hotels

# %%
hotel_dataframe = hotel_dataframe.sort_values('distance')[:8].reset_index(drop = True)
hotel_dataframe
# Out:
#                                  name categories               address  \
# 0                       Jinfeng Hotel      Hotel        143-49 Ash Ave
# 1  Marco LaGuardia Hotel by Lexington      Hotel  137-07 Northern Blvd
# 2                Flushing Grand Hotel      Hotel          3638 Main St
# 3              Flushing Central Hotel      Hotel       135-33 38th Ave
# 4               Hotel Indigo Flushing      Hotel   35-57 Prince Street
# 5            Grandview Hotel New York      Hotel       31-16 Linden Pl
# 6                       Asiatic Hotel      Hotel       135-21 37th Ave
# 7       Sheraton LaGuardia East Hotel      Hotel       135-20 39th Ave
#
#    distance        lat        lng postalCode
# 0       877  40.757871 -73.820400      11355
# 1      1166  40.763567 -73.831048      11354
# 2      1275  40.762124 -73.831916      11354
# 3      1293  40.760684 -73.831432      11354
# 4      1341  40.762430 -73.832842      11354
# 5      1341  40.768807 -73.832703      11354
# 6      1345  40.761109 -73.832337      11354
# 7      1358  40.759726 -73.831677      11354

# %% [markdown]
# ## Searching For Restaurants Within A 500 Meter Radius

# %%
# Search for restaurants within a radius of 4 Kilometeres
search_query_2 = 'Restaurant'
radius_2 = 500

# Define the corresponding URL
url_2 = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query_2, radius_2, LIMIT)
url_2
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=CX52FPGWLTFOMA4TJ3KTCYNK1OXFLEWYLJ4MMZUS0ZMHSPDU&client_secret=ACRWE2VD5G45WE5HJISORFKFJJ0DOBBVV3ZF4RGLA3HBXTB4&ll=40.7654301,-73.8174291&v=20180604&query=Restaurant&radius=500&limit=30'

# %% [markdown]
# ### Sending The GET Request And Examining The Results

# %%
results_2 = requests.get(url_2).json()
results_2
# Out:
# {'meta': {'code': 200, 'requestId': '5df4fc6c6d8c56001bdb9365'},
#  'response': {'venues': [{'id': '4ca67385b7106dcb6e3b5ea5',
#     'name': 'Bonjuk Korean Traditional Porridge Restaurant',
#     'location': {'address': '15226 Northern Blvd',
#      'lat': 40.76487281750307,
#      'lng': -73.8121110221354,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76487281750307,
#        'lng': -73.8121110221354}],
#      'distance': 452,
#      'postalCode': '11354',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['15226 Northern Blvd',
#       'Flushing, NY 11354',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d113941735',
#       'name': 'Korean Restaurant',
#       'pluralName': 'Korean Restaurants',
#       'shortName': 'Korean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336506',
#     'hasPerk': False},
#    {'id': '4e4dd8e4bd41b76bef941b5e',
#     'name': 'X-tra Cheese Pizzeria & Restaurant',
#     'location': {'address': '14720 Northern Blvd',
#      'lat': 40.765176601287514,
#      'lng': -73.81861981622363,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.765176601287514,
#        'lng': -73.81861981622363}],
#      'distance': 104,
#      'postalCode': '11354',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['14720 Northern Blvd',
#       'Flushing, NY 11354',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336506',
#     'hasPerk': False},
#    {'id': '54669f6d498e9e9b900a1353',
#     'name': 'Jeun Ju Korean Restaurant',
#     'location': {'address': '40-11 150th St',
#      'lat': 40.763244,
#      'lng': -73.814485,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.763244,
#        'lng': -73.814485}],
#      'distance': 347,
#      'postalCode': '11354',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['40-11 150th St',
#       'Flushing, NY 11354',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d113941735',
#       'name': 'Korean Restaurant',
#       'pluralName': 'Korean Restaurants',
#       'shortName': 'Korean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336506',
#     'hasPerk': False},
#    {'id': '55e7cebe498ef6a7603af18f',
#     'name': 'Well Being Family Garden Korean BBQ Restaurant',
#     'location': {'address': '41-11 150th St',
#      'lat': 40.762487,
#      'lng': -73.813687,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.762487,
#        'lng': -73.813687}],
#      'distance': 454,
#      'postalCode': '11355',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['41-11 150th St',
#       'Flushing, NY 11355',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d113941735',
#       'name': 'Korean Restaurant',
#       'pluralName': 'Korean Restaurants',
#       'shortName': 'Korean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336506',
#     'hasPerk': False},
#    {'id': '4c7ad3dda86837048bee144d',
#     'name': 'Geo Si Gi Restaurant',
#     'location': {'address': '152-28 Northern Blvd',
#      'lat': 40.764865361948935,
#      'lng': -73.81198259646033,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.764865361948935,
#        'lng': -73.81198259646033}],
#      'distance': 463,
#      'postalCode': '11354',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['152-28 Northern Blvd',
#       'Flushing, NY 11354',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d113941735',
#       'name': 'Korean Restaurant',
#       'pluralName': 'Korean Restaurants',
#       'shortName': 'Korean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336506',
#     'hasPerk': False},
#    {'id': '4b244c57f964a520806524e3',
#     'name': 'Sol Bawoo Restaurant',
#     'location': {'address': '149-44 41st Ave',
#      'lat': 40.76578201027666,
#      'lng': -73.81443132332323,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76578201027666,
#        'lng': -73.81443132332323}],
#      'distance': 255,
#      'postalCode': '11355',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['149-44 41st Ave',
#       'Flushing, NY 11355',
#       'United States']},
#     'categories': [],
#     'referralId': 'v-1576336506',
#     'hasPerk': False},
#    {'id': '4e4dd8e3bd41b76bef941b48',
#     'name': '146-13 Northern Blvd Korean Restaurant',
#     'location': {'address': '14613 Northern Blvd',
#      'lat': 40.765009,
#      'lng': -73.820516,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.765009,
#        'lng': -73.820516}],
#      'distance': 264,
#      'postalCode': '11354',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['14613 Northern Blvd',
#       'Flushing, NY 11354',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d113941735',
#       'name': 'Korean Restaurant',
#       'pluralName': 'Korean Restaurants',
#       'shortName': 'Korean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336506',
#     'hasPerk': False},
#    {'id': '4f32737319836c91c7d914f1',
#     'name': 'Sho Bu Restaurant',
#     'location': {'address': '4011 149th Pl',
#      'lat': 40.763324,
#      'lng': -73.815244,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.763324,
#        'lng': -73.815244}],
#      'distance': 298,
#      'postalCode': '11354',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['4011 149th Pl',
#       'Flushing, NY 11354',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336506',
#     'hasPerk': False},
#    {'id': '4f321dc419836c91c7b78c08',
#     'name': 'Mea So Eve Restaurant',
#     'location': {'address': '4007 150th St',
#      'lat': 40.763428,
#      'lng': -73.814311,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.763428,
#        'lng': -73.814311}],
#      'distance': 344,
#      'postalCode': '11354',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['4007 150th St',
#       'Flushing, NY 11354',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336506',
#     'hasPerk': False},
#    {'id': '4f32ac2f19836c91c7ee8abb',
#     'name': 'Golden Door Restaurant',
#     'location': {'address': '14605 34th Ave',
#      'lat': 40.767352,
#      'lng': -73.821011,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.767352,
#        'lng': -73.821011}],
#      'distance': 370,
#      'postalCode': '11354',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['14605 34th Ave',
#       'Flushing, NY 11354',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336506',
#     'hasPerk': False},
#    {'id': '4cf2e2ed1d18a14301dc5cec',
#     'name': 'El Recuerdo Restaurant & Bakery',
#     'location': {'address': '146-05 34th Ave',
#      'lat': 40.76375021143707,
#      'lng': -73.82303925139067,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76375021143707,
#        'lng': -73.82303925139067}],
#      'distance': 508,
#      'postalCode': '11354',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['146-05 34th Ave',
#       'Flushing, NY 11354',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336506',
#     'hasPerk': False},
#    {'id': '4f43e60219836ed001912166',
#     'name': 'Jjds Restaurant',
#     'location': {'address': '14914 41st Ave',
#      'lat': 40.762204,
#      'lng': -73.815372,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.762204,
#        'lng': -73.815372}],
#      'distance': 398,
#      'postalCode': '11355',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['14914 41st Ave',
#       'Flushing, NY 11355',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336506',
#     'hasPerk': False},
#    {'id': '4b64d974f964a520ced42ae3',
#     'name': 'Golden Gate Chinese Restaurant',
#     'location': {'address': '152-12 Northern Blvd',
#      'lat': 40.764701,
#      'lng': -73.812517,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.764701,
#        'lng': -73.812517}],
#      'distance': 422,
#      'postalCode': '11354',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['152-12 Northern Blvd',
#       'Flushing, NY 11354',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336506',
#     'hasPerk': False},
#    {'id': '4f32381019836c91c7c1dd5c',
#     'name': 'O S Restaurant',
#     'location': {'address': '4106 149th Pl',
#      'lat': 40.762202,
#      'lng': -73.814717,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.762202,
#        'lng': -73.814717}],
#      'distance': 425,
#      'postalCode': '11355',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['4106 149th Pl',
#       'Flushing, NY 11355',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336506',
#     'hasPerk': False},
#    {'id': '4e4dd8e2bd41b76bef941b37',
#     'name': '152-12 Northern Blvd Chinese Restaurant',
#     'location': {'address': '15212 Northern Blvd',
#      'lat': 40.764954,
#      'lng': -73.812394,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.764954,
#        'lng': -73.812394}],
#      'distance': 427,
#      'postalCode': '11354',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['15212 Northern Blvd',
#       'Flushing, NY 11354',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336506',
#     'hasPerk': False},
#    {'id': '527be2ea11d2b0bb83f62505',
#     'name': 'Sarangbang Restaurant',
#     'location': {'address': '149-44 41st Ave',
#      'lat': 40.762418,
#      'lng': -73.814275,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.762418,
#        'lng': -73.814275}],
#      'distance': 427,
#      'postalCode': '11355',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['149-44 41st Ave',
#       'Flushing, NY 11355',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d113941735',
#       'name': 'Korean Restaurant',
#       'pluralName': 'Korean Restaurants',
#       'shortName': 'Korean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336506',
#     'hasPerk': False},
#    {'id': '50d7cb2be4b0bc5a62819825',
#     'name': 'ChunBuRo Restaurant',
#     'location': {'address': '144-18 Northern Blvd',
#      'lat': 40.76471699186899,
#      'lng': -73.82266819801872,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76471699186899,
#        'lng': -73.82266819801872}],
#      'distance': 448,
#      'postalCode': '11354',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['144-18 Northern Blvd',
#       'Flushing, NY 11354',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d113941735',
#       'name': 'Korean Restaurant',
#       'pluralName': 'Korean Restaurants',
#       'shortName': 'Korean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336506',
#     'hasPerk': False},
#    {'id': '513d0492e4b02357eb1bebe5',
#     'name': 'Chun Bu Ro Restaurant',
#     'location': {'address': '144-18 Northern Blvd',
#      'lat': 40.76482,
#      'lng': -73.822864,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76482,
#        'lng': -73.822864}],
#      'distance': 463,
#      'postalCode': '11354',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['144-18 Northern Blvd',
#       'Flushing, NY 11354',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336506',
#     'hasPerk': False},
#    {'id': '4f3264ee19836c91c7d38344',
#     'name': 'Peking Chinese Restaurant',
#     'location': {'address': '14411 Northern Blvd',
#      'lat': 40.764716,
#      'lng': -73.823104,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.764716,
#        'lng': -73.823104}],
#      'distance': 485,
#      'postalCode': '11354',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['14411 Northern Blvd',
#       'Flushing, NY 11354',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336506',
#     'hasPerk': False},
#    {'id': '4b830e44f964a520ebf430e3',
#     'name': 'Hahm Ji Bach - 함지박',
#     'location': {'address': '40-11 149th Pl',
#      'lat': 40.763021787852146,
#      'lng': -73.81504155699612,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.763021787852146,
#        'lng': -73.81504155699612}],
#      'distance': 335,
#      'postalCode': '11354',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['40-11 149th Pl',
#       'Flushing, NY 11354',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d113941735',
#       'name': 'Korean Restaurant',
#       'pluralName': 'Korean Restaurants',
#       'shortName': 'Korean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336506',
#     'hasPerk': False},
#    {'id': '4c35fd6e16adc928439fc79c',
#     'name': 'Sweets Bakery Cafe',
#     'location': {'address': '144-06 Northern Blvd',
#      'lat': 40.76373309958273,
#      'lng': -73.82298755667173,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76373309958273,
#        'lng': -73.82298755667173}],
#      'distance': 505,
#      'postalCode': '11354',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['144-06 Northern Blvd',
#       'Flushing, NY 11354',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '559301',
#      'url': 'https://www.seamless.com/menu/sweets-bakery--cafe-14406-northern-blvd-flushing/559301?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=559301',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1576336506',
#     'hasPerk': False},
#    {'id': '4baeabe6f964a52037cd3be3',
#     'name': 'Kum Sung Chik Naengmyun',
#     'location': {'address': '40-07 149th Pl',
#      'lat': 40.76312208490418,
#      'lng': -73.81509111682782,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76312208490418,
#        'lng': -73.81509111682782}],
#      'distance': 323,
#      'postalCode': '11354',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['40-07 149th Pl',
#       'Flushing, NY 11354',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d113941735',
#       'name': 'Korean Restaurant',
#       'pluralName': 'Korean Restaurants',
#       'shortName': 'Korean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336506',
#     'hasPerk': False},
#    {'id': '4ad3bfabf964a52016e620e3',
#     'name': 'Han Joo',
#     'location': {'address': '41-06 149th Pl',
#      'crossStreet': 'at 41st Ave',
#      'lat': 40.762274065368665,
#      'lng': -73.8147692298185,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.762274065368665,
#        'lng': -73.8147692298185}],
#      'distance': 416,
#      'postalCode': '11355',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['41-06 149th Pl (at 41st Ave)',
#       'Flushing, NY 11355',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d113941735',
#       'name': 'Korean Restaurant',
#       'pluralName': 'Korean Restaurants',
#       'shortName': 'Korean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336506',
#     'hasPerk': False}]}}

# %% [markdown]
# ### Assigning Relevant Part Of The JSON To Venues And Transforming The Venues Into A DataFrame

# %%
venues_2 = results_2['response']['venues']

dataframe_restaurant = json_normalize(venues_2)
dataframe_restaurant.head()
# Out:
#                                           categories delivery.id  \
# 0  [{'id': '4bf58dd8d48988d113941735', 'name': 'K...         NaN
# 1  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...         NaN
# 2  [{'id': '4bf58dd8d48988d113941735', 'name': 'K...         NaN
# 3  [{'id': '4bf58dd8d48988d113941735', 'name': 'K...         NaN
# 4  [{'id': '4bf58dd8d48988d113941735', 'name': 'K...         NaN
#
#   delivery.provider.icon.name delivery.provider.icon.prefix  \
# 0                         NaN                           NaN
# 1                         NaN                           NaN
# 2                         NaN                           NaN
# 3                         NaN                           NaN
# 4                         NaN                           NaN
#
#   delivery.provider.icon.sizes delivery.provider.name delivery.url  hasPerk  \
# 0                          NaN                    NaN          NaN    False
# 1                          NaN                    NaN          NaN    False
# 2                          NaN                    NaN          NaN    False
# 3                          NaN                    NaN          NaN    False
# 4                          NaN                    NaN          NaN    False
#
#                          id      location.address  ... location.crossStreet  \
# 0  4ca67385b7106dcb6e3b5ea5   15226 Northern Blvd  ...                  NaN
# 1  4e4dd8e4bd41b76bef941b5e   14720 Northern Blvd  ...                  NaN
# 2  54669f6d498e9e9b900a1353        40-11 150th St  ...                  NaN
# 3  55e7cebe498ef6a7603af18f        41-11 150th St  ...                  NaN
# 4  4c7ad3dda86837048bee144d  152-28 Northern Blvd  ...                  NaN
#
#   location.distance                          location.formattedAddress  \
# 0               452  [15226 Northern Blvd, Flushing, NY 11354, Unit...
# 1               104  [14720 Northern Blvd, Flushing, NY 11354, Unit...
# 2               347  [40-11 150th St, Flushing, NY 11354, United St...
# 3               454  [41-11 150th St, Flushing, NY 11355, United St...
# 4               463  [152-28 Northern Blvd, Flushing, NY 11354, Uni...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 40.76487281750307...     40.764873
# 1  [{'label': 'display', 'lat': 40.76517660128751...     40.765177
# 2  [{'label': 'display', 'lat': 40.763244, 'lng':...     40.763244
# 3  [{'label': 'display', 'lat': 40.762487, 'lng':...     40.762487
# 4  [{'label': 'display', 'lat': 40.76486536194893...     40.764865
#
#   location.lng location.postalCode  location.state  \
# 0   -73.812111               11354              NY
# 1   -73.818620               11354              NY
# 2   -73.814485               11354              NY
# 3   -73.813687               11355              NY
# 4   -73.811983               11354              NY
#
#                                              name    referralId
# 0   Bonjuk Korean Traditional Porridge Restaurant  v-1576336506
# 1              X-tra Cheese Pizzeria & Restaurant  v-1576336506
# 2                       Jeun Ju Korean Restaurant  v-1576336506
# 3  Well Being Family Garden Korean BBQ Restaurant  v-1576336506
# 4                            Geo Si Gi Restaurant  v-1576336506
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Cleaning The DataFrame

# %%
# Keep only columns that include venue name, and anything that is associated with location
new_columns_2 = ['name', 'categories'] + [col for col in dataframe_restaurant.columns if col.startswith('location.')]+ ['id']
new_dataframe_restaurant = dataframe_restaurant.loc[:, new_columns_2]

# Function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# Filter the category for each row
new_dataframe_restaurant['categories'] = new_dataframe_restaurant.apply(get_category_type, axis=1)

# Clean column names by keeping only last term
new_dataframe_restaurant.columns = [column.split('.')[-1] for column in new_dataframe_restaurant.columns]

new_dataframe_restaurant.head()
# Out:
#                                              name         categories  \
# 0   Bonjuk Korean Traditional Porridge Restaurant  Korean Restaurant
# 1              X-tra Cheese Pizzeria & Restaurant        Pizza Place
# 2                       Jeun Ju Korean Restaurant  Korean Restaurant
# 3  Well Being Family Garden Korean BBQ Restaurant  Korean Restaurant
# 4                            Geo Si Gi Restaurant  Korean Restaurant
#
#                 address  cc      city        country crossStreet  distance  \
# 0   15226 Northern Blvd  US  Flushing  United States         NaN       452
# 1   14720 Northern Blvd  US  Flushing  United States         NaN       104
# 2        40-11 150th St  US  Flushing  United States         NaN       347
# 3        41-11 150th St  US  Flushing  United States         NaN       454
# 4  152-28 Northern Blvd  US  Flushing  United States         NaN       463
#
#                                     formattedAddress  \
# 0  [15226 Northern Blvd, Flushing, NY 11354, Unit...
# 1  [14720 Northern Blvd, Flushing, NY 11354, Unit...
# 2  [40-11 150th St, Flushing, NY 11354, United St...
# 3  [41-11 150th St, Flushing, NY 11355, United St...
# 4  [152-28 Northern Blvd, Flushing, NY 11354, Uni...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 40.76487281750307...  40.764873 -73.812111
# 1  [{'label': 'display', 'lat': 40.76517660128751...  40.765177 -73.818620
# 2  [{'label': 'display', 'lat': 40.763244, 'lng':...  40.763244 -73.814485
# 3  [{'label': 'display', 'lat': 40.762487, 'lng':...  40.762487 -73.813687
# 4  [{'label': 'display', 'lat': 40.76486536194893...  40.764865 -73.811983
#
#   postalCode state                        id
# 0      11354    NY  4ca67385b7106dcb6e3b5ea5
# 1      11354    NY  4e4dd8e4bd41b76bef941b5e
# 2      11354    NY  54669f6d498e9e9b900a1353
# 3      11355    NY  55e7cebe498ef6a7603af18f
# 4      11354    NY  4c7ad3dda86837048bee144d

# %% [markdown]
# ### Dropping Useless Columns

# %%
new_dataframe_restaurant2 = new_dataframe_restaurant.drop(['cc', 'city', 'country', 'crossStreet', 'formattedAddress', 'labeledLatLngs', 'state', 'id'], axis=1)
new_dataframe_restaurant2
# Out:
#                                               name          categories  \
# 0    Bonjuk Korean Traditional Porridge Restaurant   Korean Restaurant
# 1               X-tra Cheese Pizzeria & Restaurant         Pizza Place
# 2                        Jeun Ju Korean Restaurant   Korean Restaurant
# 3   Well Being Family Garden Korean BBQ Restaurant   Korean Restaurant
# 4                             Geo Si Gi Restaurant   Korean Restaurant
# 5                             Sol Bawoo Restaurant                None
# 6           146-13 Northern Blvd Korean Restaurant   Korean Restaurant
# 7                                Sho Bu Restaurant                Food
# 8                            Mea So Eve Restaurant                Food
# 9                           Golden Door Restaurant         Pizza Place
# 10                 El Recuerdo Restaurant & Bakery              Bakery
# 11                                 Jjds Restaurant                Food
# 12                  Golden Gate Chinese Restaurant  Chinese Restaurant
# 13                                  O S Restaurant                Food
# 14         152-12 Northern Blvd Chinese Restaurant  Chinese Restaurant
# 15                           Sarangbang Restaurant   Korean Restaurant
# 16                             ChunBuRo Restaurant   Korean Restaurant
# 17                           Chun Bu Ro Restaurant  Chinese Restaurant
# 18                       Peking Chinese Restaurant  Chinese Restaurant
# 19                              Hahm Ji Bach - 함지박   Korean Restaurant
# 20                              Sweets Bakery Cafe  Chinese Restaurant
# 21                         Kum Sung Chik Naengmyun   Korean Restaurant
# 22                                         Han Joo   Korean Restaurant
#
#                  address  distance        lat        lng postalCode
# 0    15226 Northern Blvd       452  40.764873 -73.812111      11354
# 1    14720 Northern Blvd       104  40.765177 -73.818620      11354
# 2         40-11 150th St       347  40.763244 -73.814485      11354
# 3         41-11 150th St       454  40.762487 -73.813687      11355
# 4   152-28 Northern Blvd       463  40.764865 -73.811983      11354
# 5        149-44 41st Ave       255  40.765782 -73.814431      11355
# 6    14613 Northern Blvd       264  40.765009 -73.820516      11354
# 7          4011 149th Pl       298  40.763324 -73.815244      11354
# 8          4007 150th St       344  40.763428 -73.814311      11354
# 9         14605 34th Ave       370  40.767352 -73.821011      11354
# 10       146-05 34th Ave       508  40.763750 -73.823039      11354
# 11        14914 41st Ave       398  40.762204 -73.815372      11355
# 12  152-12 Northern Blvd       422  40.764701 -73.812517      11354
# 13         4106 149th Pl       425  40.762202 -73.814717      11355
# 14   15212 Northern Blvd       427  40.764954 -73.812394      11354
# 15       149-44 41st Ave       427  40.762418 -73.814275      11355
# 16  144-18 Northern Blvd       448  40.764717 -73.822668      11354
# 17  144-18 Northern Blvd       463  40.764820 -73.822864      11354
# 18   14411 Northern Blvd       485  40.764716 -73.823104      11354
# 19        40-11 149th Pl       335  40.763022 -73.815042      11354
# 20  144-06 Northern Blvd       505  40.763733 -73.822988      11354
# 21        40-07 149th Pl       323  40.763122 -73.815091      11354
# 22        41-06 149th Pl       416  40.762274 -73.814769      11355

# %% [markdown]
# ### Deleting Rows With NaN or Null Values

# %%
new_dataframe_restaurant3 = new_dataframe_restaurant2.dropna(axis=0)
new_dataframe_restaurant3
# Out:
#                                               name          categories  \
# 0    Bonjuk Korean Traditional Porridge Restaurant   Korean Restaurant
# 1               X-tra Cheese Pizzeria & Restaurant         Pizza Place
# 2                        Jeun Ju Korean Restaurant   Korean Restaurant
# 3   Well Being Family Garden Korean BBQ Restaurant   Korean Restaurant
# 4                             Geo Si Gi Restaurant   Korean Restaurant
# 6           146-13 Northern Blvd Korean Restaurant   Korean Restaurant
# 7                                Sho Bu Restaurant                Food
# 8                            Mea So Eve Restaurant                Food
# 9                           Golden Door Restaurant         Pizza Place
# 10                 El Recuerdo Restaurant & Bakery              Bakery
# 11                                 Jjds Restaurant                Food
# 12                  Golden Gate Chinese Restaurant  Chinese Restaurant
# 13                                  O S Restaurant                Food
# 14         152-12 Northern Blvd Chinese Restaurant  Chinese Restaurant
# 15                           Sarangbang Restaurant   Korean Restaurant
# 16                             ChunBuRo Restaurant   Korean Restaurant
# 17                           Chun Bu Ro Restaurant  Chinese Restaurant
# 18                       Peking Chinese Restaurant  Chinese Restaurant
# 19                              Hahm Ji Bach - 함지박   Korean Restaurant
# 20                              Sweets Bakery Cafe  Chinese Restaurant
# 21                         Kum Sung Chik Naengmyun   Korean Restaurant
# 22                                         Han Joo   Korean Restaurant
#
#                  address  distance        lat        lng postalCode
# 0    15226 Northern Blvd       452  40.764873 -73.812111      11354
# 1    14720 Northern Blvd       104  40.765177 -73.818620      11354
# 2         40-11 150th St       347  40.763244 -73.814485      11354
# 3         41-11 150th St       454  40.762487 -73.813687      11355
# 4   152-28 Northern Blvd       463  40.764865 -73.811983      11354
# 6    14613 Northern Blvd       264  40.765009 -73.820516      11354
# 7          4011 149th Pl       298  40.763324 -73.815244      11354
# 8          4007 150th St       344  40.763428 -73.814311      11354
# 9         14605 34th Ave       370  40.767352 -73.821011      11354
# 10       146-05 34th Ave       508  40.763750 -73.823039      11354
# 11        14914 41st Ave       398  40.762204 -73.815372      11355
# 12  152-12 Northern Blvd       422  40.764701 -73.812517      11354
# 13         4106 149th Pl       425  40.762202 -73.814717      11355
# 14   15212 Northern Blvd       427  40.764954 -73.812394      11354
# 15       149-44 41st Ave       427  40.762418 -73.814275      11355
# 16  144-18 Northern Blvd       448  40.764717 -73.822668      11354
# 17  144-18 Northern Blvd       463  40.764820 -73.822864      11354
# 18   14411 Northern Blvd       485  40.764716 -73.823104      11354
# 19        40-11 149th Pl       335  40.763022 -73.815042      11354
# 20  144-06 Northern Blvd       505  40.763733 -73.822988      11354
# 21        40-07 149th Pl       323  40.763122 -73.815091      11354
# 22        41-06 149th Pl       416  40.762274 -73.814769      11355

# %% [markdown]
# ### Sorting According To Distance From The Academy and Selecting The Nearest Eight

# %%
new_dataframe_restaurant3 = new_dataframe_restaurant3.sort_values('distance')[:8].reset_index(drop = True)
new_dataframe_restaurant3
# Out:
#                                      name         categories  \
# 0      X-tra Cheese Pizzeria & Restaurant        Pizza Place
# 1  146-13 Northern Blvd Korean Restaurant  Korean Restaurant
# 2                       Sho Bu Restaurant               Food
# 3                 Kum Sung Chik Naengmyun  Korean Restaurant
# 4                      Hahm Ji Bach - 함지박  Korean Restaurant
# 5                   Mea So Eve Restaurant               Food
# 6               Jeun Ju Korean Restaurant  Korean Restaurant
# 7                  Golden Door Restaurant        Pizza Place
#
#                address  distance        lat        lng postalCode
# 0  14720 Northern Blvd       104  40.765177 -73.818620      11354
# 1  14613 Northern Blvd       264  40.765009 -73.820516      11354
# 2        4011 149th Pl       298  40.763324 -73.815244      11354
# 3       40-07 149th Pl       323  40.763122 -73.815091      11354
# 4       40-11 149th Pl       335  40.763022 -73.815042      11354
# 5        4007 150th St       344  40.763428 -73.814311      11354
# 6       40-11 150th St       347  40.763244 -73.814485      11354
# 7       14605 34th Ave       370  40.767352 -73.821011      11354

# %% [markdown]
# ## Searching For Gyms Within A 3 KM Radius

# %%
# Search for restaurants within a radius of 4 Kilometeres
search_query_3 = 'Gym'
radius_3 = 2000

# Define the corresponding URL
url_3 = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query_3, radius_3, LIMIT)
url_3
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=CX52FPGWLTFOMA4TJ3KTCYNK1OXFLEWYLJ4MMZUS0ZMHSPDU&client_secret=ACRWE2VD5G45WE5HJISORFKFJJ0DOBBVV3ZF4RGLA3HBXTB4&ll=40.7654301,-73.8174291&v=20180604&query=Gym&radius=2000&limit=30'

# %% [markdown]
# ### Sending The GET Request And Examining The Results

# %%
results_3 = requests.get(url_3).json()
results_3
# Out:
# {'meta': {'code': 200, 'requestId': '5df4fc7dbe61c9001bc770e3'},
#  'response': {'venues': [{'id': '54124898498eb4c762dd4406',
#     'name': 'Skyview Parc Gym',
#     'location': {'lat': 40.75758537730301,
#      'lng': -73.83586419053327,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75758537730301,
#        'lng': -73.83586419053327}],
#      'distance': 1782,
#      'postalCode': '11354',
#      'cc': 'US',
#      'city': 'Queens',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Queens, NY 11354', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336508',
#     'hasPerk': False},
#    {'id': '4c84579cd34ca1439c4b3e80',
#     'name': 'Gym Metro',
#     'location': {'address': '164-24 Northern Blvd',
#      'crossStreet': 'Sanford Ave',
#      'lat': 40.76032416509134,
#      'lng': -73.80124561272534,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76032416509134,
#        'lng': -73.80124561272534}],
#      'distance': 1478,
#      'postalCode': '11358',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['164-24 Northern Blvd (Sanford Ave)',
#       'Flushing, NY 11358',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336508',
#     'hasPerk': False},
#    {'id': '4ada2a35f964a520601f21e3',
#     'name': 'Power House Gym',
#     'location': {'address': '34-09 Francis Lewis Blvd',
#      'crossStreet': 'at 34th Ave',
#      'lat': 40.76601818858601,
#      'lng': -73.78928234831177,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76601818858601,
#        'lng': -73.78928234831177}],
#      'distance': 2373,
#      'postalCode': '11358',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['34-09 Francis Lewis Blvd (at 34th Ave)',
#       'Flushing, NY 11358',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336508',
#     'hasPerk': False},
#    {'id': '4f18a41be4b0242771b0dc92',
#     'name': 'GYM-MyRunningWheeL',
#     'location': {'lat': 40.765720085283974,
#      'lng': -73.82493180876845,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.765720085283974,
#        'lng': -73.82493180876845}],
#      'distance': 633,
#      'postalCode': '11354',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Flushing, NY 11354', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336508',
#     'hasPerk': False},
#    {'id': '4f9f05bce4b060916ab65a8f',
#     'name': 'gym',
#     'location': {'address': 'Hoover Ave, Queens, NY 11435',
#      'lat': 40.77246123927427,
#      'lng': -73.82799268997377,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.77246123927427,
#        'lng': -73.82799268997377}],
#      'distance': 1185,
#      'postalCode': '11435',
#      'cc': 'US',
#      'city': 'Queens',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Hoover Ave, Queens, NY 11435',
#       'Queens, NY 11435',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336508',
#     'hasPerk': False},
#    {'id': '51363087e4b0caef3a2c7943',
#     'name': "Gatita's Gym",
#     'location': {'lat': 40.7637939453125,
#      'lng': -73.82310485839844,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7637939453125,
#        'lng': -73.82310485839844}],
#      'distance': 512,
#      'cc': 'US',
#      'city': 'Queens',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Queens, NY', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336508',
#     'hasPerk': False},
#    {'id': '4d23d30e5d7d2d43f80a9310',
#     'name': 'Murray Hill - Outdoor Gym',
#     'location': {'address': '32nd Avenue',
#      'crossStreet': '154th Street',
#      'lat': 40.77288439698284,
#      'lng': -73.81007737791315,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.77288439698284,
#        'lng': -73.81007737791315}],
#      'distance': 1035,
#      'postalCode': '11354',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['32nd Avenue (154th Street)',
#       'Flushing, NY 11354',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d162941735',
#       'name': 'Other Great Outdoors',
#       'pluralName': 'Other Great Outdoors',
#       'shortName': 'Other Outdoors',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/outdoors_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336508',
#     'hasPerk': False},
#    {'id': '57470f36498ec1626794e9af',
#     'name': 'PD 109 Gym',
#     'location': {'lat': 40.76236461089549,
#      'lng': -73.82744129292522,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76236461089549,
#        'lng': -73.82744129292522}],
#      'distance': 910,
#      'cc': 'US',
#      'city': 'Queens',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Queens, NY', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336508',
#     'hasPerk': False},
#    {'id': '4d48fd86183f224b5c7cd9a8',
#     'name': 'The Gym',
#     'location': {'lat': 40.765356,
#      'lng': -73.83488,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.765356,
#        'lng': -73.83488}],
#      'distance': 1471,
#      'postalCode': '11354',
#      'cc': 'US',
#      'state': 'New York',
#      'country': 'United States',
#      'formattedAddress': ['NY 11354', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336508',
#     'hasPerk': False},
#    {'id': '51168ce6e4b0f8a4c5b10a01',
#     'name': 'Eight Limb Muay Thai Boxing Gym',
#     'location': {'lat': 40.77985413130354,
#      'lng': -73.81207048233858,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.77985413130354,
#        'lng': -73.81207048233858}],
#      'distance': 1668,
#      'postalCode': '11357',
#      'cc': 'US',
#      'city': 'Whitestone',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Whitestone, NY 11357', 'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b47',
#       'name': 'Boxing Gym',
#       'pluralName': 'Boxing Gyms',
#       'shortName': 'Boxing Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336508',
#     'hasPerk': False},
#    {'id': '4c89076b584c76b04d37ee58',
#     'name': 'glaceau gym',
#     'location': {'address': '17-20 Whitestone Expy',
#      'lat': 40.784075,
#      'lng': -73.825109,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.784075,
#        'lng': -73.825109}],
#      'distance': 2174,
#      'postalCode': '11357',
#      'cc': 'US',
#      'city': 'Whitestone',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['17-20 Whitestone Expy',
#       'Whitestone, NY 11357',
#       'United States']},
#     'categories': [],
#     'referralId': 'v-1576336508',
#     'hasPerk': False},
#    {'id': '4bc4e501b492d13a8abbaa60',
#     'name': 'Park City Gymnastics',
#     'location': {'address': '170-16 39th Ave',
#      'lat': 40.76157171361488,
#      'lng': -73.79567069883336,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76157171361488,
#        'lng': -73.79567069883336}],
#      'distance': 1884,
#      'postalCode': '11358',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['170-16 39th Ave',
#       'Flushing, NY 11358',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b48',
#       'name': 'Gymnastics Gym',
#       'pluralName': 'Gymnastics Gyms',
#       'shortName': 'Gymnastics Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336508',
#     'hasPerk': False},
#    {'id': '5331fab9498ea7e292c76513',
#     'name': 'isadora rhythmic gymnastics',
#     'location': {'address': '137-44 Northern Blvd',
#      'crossStreet': 'Union',
#      'lat': 40.76351322573997,
#      'lng': -73.83044523947417,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76351322573997,
#        'lng': -73.83044523947417}],
#      'distance': 1117,
#      'postalCode': '11354',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['137-44 Northern Blvd (Union)',
#       'Flushing, NY 11354',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b48',
#       'name': 'Gymnastics Gym',
#       'pluralName': 'Gymnastics Gyms',
#       'shortName': 'Gymnastics Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576336508',
#     'hasPerk': False}]}}

# %% [markdown]
# ### Assigning Relevant Part Of The JSON To Venues And Transforming The Venues Into A DataFrame

# %%
venues_3 = results_3['response']['venues']

dataframe_gym = json_normalize(venues_3)
dataframe_gym.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...    False
# 1  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...    False
# 2  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...    False
# 3  [{'id': '4bf58dd8d48988d175941735', 'name': 'G...    False
# 4  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...    False
#
#                          id              location.address location.cc  \
# 0  54124898498eb4c762dd4406                           NaN          US
# 1  4c84579cd34ca1439c4b3e80          164-24 Northern Blvd          US
# 2  4ada2a35f964a520601f21e3      34-09 Francis Lewis Blvd          US
# 3  4f18a41be4b0242771b0dc92                           NaN          US
# 4  4f9f05bce4b060916ab65a8f  Hoover Ave, Queens, NY 11435          US
#
#   location.city location.country location.crossStreet  location.distance  \
# 0        Queens    United States                  NaN               1782
# 1      Flushing    United States          Sanford Ave               1478
# 2      Flushing    United States          at 34th Ave               2373
# 3      Flushing    United States                  NaN                633
# 4        Queens    United States                  NaN               1185
#
#                            location.formattedAddress  \
# 0                  [Queens, NY 11354, United States]
# 1  [164-24 Northern Blvd (Sanford Ave), Flushing,...
# 2  [34-09 Francis Lewis Blvd (at 34th Ave), Flush...
# 3                [Flushing, NY 11354, United States]
# 4  [Hoover Ave, Queens, NY 11435, Queens, NY 1143...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 40.75758537730301...     40.757585
# 1  [{'label': 'display', 'lat': 40.76032416509134...     40.760324
# 2  [{'label': 'display', 'lat': 40.76601818858601...     40.766018
# 3  [{'label': 'display', 'lat': 40.76572008528397...     40.765720
# 4  [{'label': 'display', 'lat': 40.77246123927427...     40.772461
#
#    location.lng location.postalCode location.state                name  \
# 0    -73.835864               11354             NY    Skyview Parc Gym
# 1    -73.801246               11358             NY           Gym Metro
# 2    -73.789282               11358             NY     Power House Gym
# 3    -73.824932               11354             NY  GYM-MyRunningWheeL
# 4    -73.827993               11435             NY                 gym
#
#      referralId
# 0  v-1576336508
# 1  v-1576336508
# 2  v-1576336508
# 3  v-1576336508
# 4  v-1576336508

# %% [markdown]
# ### Cleaning The DataFrame

# %%
# Keep only columns that include venue name, and anything that is associated with location
new_columns_3 = ['name', 'categories'] + [col for col in dataframe_gym.columns if col.startswith('location.')]+ ['id']
new_dataframe_gym = dataframe_gym.loc[:, new_columns_3]

# Function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# Filter the category for each row
new_dataframe_gym['categories'] = new_dataframe_gym.apply(get_category_type, axis=1)

# Clean column names by keeping only last term
new_dataframe_gym.columns = [column.split('.')[-1] for column in new_dataframe_gym.columns]

new_dataframe_gym.head()
# Out:
#                  name            categories                       address  cc  \
# 0    Skyview Parc Gym                   Gym                           NaN  US
# 1           Gym Metro                   Gym          164-24 Northern Blvd  US
# 2     Power House Gym                   Gym      34-09 Francis Lewis Blvd  US
# 3  GYM-MyRunningWheeL  Gym / Fitness Center                           NaN  US
# 4                 gym                   Gym  Hoover Ave, Queens, NY 11435  US
#
#        city        country  crossStreet  distance  \
# 0    Queens  United States          NaN      1782
# 1  Flushing  United States  Sanford Ave      1478
# 2  Flushing  United States  at 34th Ave      2373
# 3  Flushing  United States          NaN       633
# 4    Queens  United States          NaN      1185
#
#                                     formattedAddress  \
# 0                  [Queens, NY 11354, United States]
# 1  [164-24 Northern Blvd (Sanford Ave), Flushing,...
# 2  [34-09 Francis Lewis Blvd (at 34th Ave), Flush...
# 3                [Flushing, NY 11354, United States]
# 4  [Hoover Ave, Queens, NY 11435, Queens, NY 1143...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 40.75758537730301...  40.757585 -73.835864
# 1  [{'label': 'display', 'lat': 40.76032416509134...  40.760324 -73.801246
# 2  [{'label': 'display', 'lat': 40.76601818858601...  40.766018 -73.789282
# 3  [{'label': 'display', 'lat': 40.76572008528397...  40.765720 -73.824932
# 4  [{'label': 'display', 'lat': 40.77246123927427...  40.772461 -73.827993
#
#   postalCode state                        id
# 0      11354    NY  54124898498eb4c762dd4406
# 1      11358    NY  4c84579cd34ca1439c4b3e80
# 2      11358    NY  4ada2a35f964a520601f21e3
# 3      11354    NY  4f18a41be4b0242771b0dc92
# 4      11435    NY  4f9f05bce4b060916ab65a8f

# %% [markdown]
# ### Dropping Useless Columns

# %%
new_dataframe_gym2 = new_dataframe_gym.drop(['cc', 'city', 'country', 'crossStreet', 'formattedAddress', 'labeledLatLngs', 'state', 'id'], axis=1)
new_dataframe_gym2
# Out:
#                                name            categories  \
# 0                  Skyview Parc Gym                   Gym
# 1                         Gym Metro                   Gym
# 2                   Power House Gym                   Gym
# 3                GYM-MyRunningWheeL  Gym / Fitness Center
# 4                               gym                   Gym
# 5                      Gatita's Gym                   Gym
# 6         Murray Hill - Outdoor Gym  Other Great Outdoors
# 7                        PD 109 Gym                   Gym
# 8                           The Gym                   Gym
# 9   Eight Limb Muay Thai Boxing Gym            Boxing Gym
# 10                      glaceau gym                  None
# 11             Park City Gymnastics        Gymnastics Gym
# 12      isadora rhythmic gymnastics        Gymnastics Gym
#
#                          address  distance        lat        lng postalCode
# 0                            NaN      1782  40.757585 -73.835864      11354
# 1           164-24 Northern Blvd      1478  40.760324 -73.801246      11358
# 2       34-09 Francis Lewis Blvd      2373  40.766018 -73.789282      11358
# 3                            NaN       633  40.765720 -73.824932      11354
# 4   Hoover Ave, Queens, NY 11435      1185  40.772461 -73.827993      11435
# 5                            NaN       512  40.763794 -73.823105        NaN
# 6                    32nd Avenue      1035  40.772884 -73.810077      11354
# 7                            NaN       910  40.762365 -73.827441        NaN
# 8                            NaN      1471  40.765356 -73.834880      11354
# 9                            NaN      1668  40.779854 -73.812070      11357
# 10         17-20 Whitestone Expy      2174  40.784075 -73.825109      11357
# 11               170-16 39th Ave      1884  40.761572 -73.795671      11358
# 12          137-44 Northern Blvd      1117  40.763513 -73.830445      11354

# %% [markdown]
# ### Deleting Rows With NaN Or Null Values

# %%
new_dataframe_gym3 = new_dataframe_gym2.dropna(axis=0)
new_dataframe_gym3
# Out:
#                            name            categories  \
# 1                     Gym Metro                   Gym
# 2               Power House Gym                   Gym
# 4                           gym                   Gym
# 6     Murray Hill - Outdoor Gym  Other Great Outdoors
# 11         Park City Gymnastics        Gymnastics Gym
# 12  isadora rhythmic gymnastics        Gymnastics Gym
#
#                          address  distance        lat        lng postalCode
# 1           164-24 Northern Blvd      1478  40.760324 -73.801246      11358
# 2       34-09 Francis Lewis Blvd      2373  40.766018 -73.789282      11358
# 4   Hoover Ave, Queens, NY 11435      1185  40.772461 -73.827993      11435
# 6                    32nd Avenue      1035  40.772884 -73.810077      11354
# 11               170-16 39th Ave      1884  40.761572 -73.795671      11358
# 12          137-44 Northern Blvd      1117  40.763513 -73.830445      11354

# %% [markdown]
# ### Deleting Rows Where The Category Is Not Gym

# %%
gym_dataframe= new_dataframe_gym3.loc[new_dataframe_gym3['categories'] == 'Gym']
gym_dataframe
# Out:
#               name categories                       address  distance  \
# 1        Gym Metro        Gym          164-24 Northern Blvd      1478
# 2  Power House Gym        Gym      34-09 Francis Lewis Blvd      2373
# 4              gym        Gym  Hoover Ave, Queens, NY 11435      1185
#
#          lat        lng postalCode
# 1  40.760324 -73.801246      11358
# 2  40.766018 -73.789282      11358
# 4  40.772461 -73.827993      11435

# %% [markdown]
# ### Sorting According To Distance From The Academy and Selecting The Nearest Three

# %%
gym_dataframe = gym_dataframe.sort_values('distance')[:3].reset_index(drop = True)
gym_dataframe
# Out:
#               name categories                       address  distance  \
# 0              gym        Gym  Hoover Ave, Queens, NY 11435      1185
# 1        Gym Metro        Gym          164-24 Northern Blvd      1478
# 2  Power House Gym        Gym      34-09 Francis Lewis Blvd      2373
#
#          lat        lng postalCode
# 0  40.772461 -73.827993      11435
# 1  40.760324 -73.801246      11358
# 2  40.766018 -73.789282      11358

# %% [markdown]
# ## Visualising The Locations Identified On A Map Centered Around The Venue

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=14) 

# add a red circle marker to represent the Tennis Academy
folium.features.CircleMarker(
    [latitude, longitude],
    radius = 7,
    color = 'red',
    popup = 'Tennis Academy',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# Adding Restaurants in green circles
for lat, lng, name in zip(new_dataframe_restaurant3.lat, new_dataframe_restaurant3.lng, new_dataframe_restaurant3.name):
    folium.features.CircleMarker(
        [lat, lng],
        radius = 3,
        color = 'green',
        popup = name,
        fill = True,
        fill_color = 'green',
        fill_opacity = 0.6
).add_to(venues_map)

# Adding Hotels in blue circles
for lat, lng, name in zip(hotel_dataframe.lat, hotel_dataframe.lng, hotel_dataframe.name):
    folium.features.CircleMarker(
        [lat, lng],
        radius = 3,
        color = 'blue',
        popup = name,
        fill = True,
        fill_color = 'blue',
        fill_opacity = 0.6
).add_to(venues_map)

# Adding Gyms in black circles
for lat, lng, name in zip(gym_dataframe.lat, gym_dataframe.lng, gym_dataframe.name):
    folium.features.CircleMarker(
        [lat, lng],
        radius = 3,
        color = 'black',
        popup = name,
        fill = True,
        fill_color = 'black',
        fill_opacity = 0.6
).add_to(venues_map)

venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Results <a name="results"></a>

# %% [markdown]
# ### The suitable Hotels that have been identified are represented by the following DataFrame

# %%
hotel_dataframe
# Out:
#                                  name categories               address  \
# 0                       Jinfeng Hotel      Hotel        143-49 Ash Ave
# 1  Marco LaGuardia Hotel by Lexington      Hotel  137-07 Northern Blvd
# 2                Flushing Grand Hotel      Hotel          3638 Main St
# 3              Flushing Central Hotel      Hotel       135-33 38th Ave
# 4               Hotel Indigo Flushing      Hotel   35-57 Prince Street
# 5            Grandview Hotel New York      Hotel       31-16 Linden Pl
# 6                       Asiatic Hotel      Hotel       135-21 37th Ave
# 7       Sheraton LaGuardia East Hotel      Hotel       135-20 39th Ave
#
#    distance        lat        lng postalCode
# 0       877  40.757871 -73.820400      11355
# 1      1166  40.763567 -73.831048      11354
# 2      1275  40.762124 -73.831916      11354
# 3      1293  40.760684 -73.831432      11354
# 4      1341  40.762430 -73.832842      11354
# 5      1341  40.768807 -73.832703      11354
# 6      1345  40.761109 -73.832337      11354
# 7      1358  40.759726 -73.831677      11354

# %% [markdown]
# ### The suitable Restaurants that have been identified are represented by the following DataFrame

# %%
new_dataframe_restaurant3
# Out:
#                                      name         categories  \
# 0      X-tra Cheese Pizzeria & Restaurant        Pizza Place
# 1  146-13 Northern Blvd Korean Restaurant  Korean Restaurant
# 2                       Sho Bu Restaurant               Food
# 3                 Kum Sung Chik Naengmyun  Korean Restaurant
# 4                      Hahm Ji Bach - 함지박  Korean Restaurant
# 5                   Mea So Eve Restaurant               Food
# 6               Jeun Ju Korean Restaurant  Korean Restaurant
# 7                  Golden Door Restaurant        Pizza Place
#
#                address  distance        lat        lng postalCode
# 0  14720 Northern Blvd       104  40.765177 -73.818620      11354
# 1  14613 Northern Blvd       264  40.765009 -73.820516      11354
# 2        4011 149th Pl       298  40.763324 -73.815244      11354
# 3       40-07 149th Pl       323  40.763122 -73.815091      11354
# 4       40-11 149th Pl       335  40.763022 -73.815042      11354
# 5        4007 150th St       344  40.763428 -73.814311      11354
# 6       40-11 150th St       347  40.763244 -73.814485      11354
# 7       14605 34th Ave       370  40.767352 -73.821011      11354

# %% [markdown]
# ### The suitable Gyms that have been identified are represented by the following DataFrame

# %%
gym_dataframe
# Out:
#               name categories                       address  distance  \
# 0              gym        Gym  Hoover Ave, Queens, NY 11435      1185
# 1        Gym Metro        Gym          164-24 Northern Blvd      1478
# 2  Power House Gym        Gym      34-09 Francis Lewis Blvd      2373
#
#          lat        lng postalCode
# 0  40.772461 -73.827993      11435
# 1  40.760324 -73.801246      11358
# 2  40.766018 -73.789282      11358

# %% [markdown]
# ### The visualization of all the locations of interest on a map centered around the venue is represented below. The red point represents the venue whereas the blue, green and black points represent the Hotels, Restaurants and Gyms identified, respectively.

# %%
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Discussion <a name="discussion"></a>
# The analysis shows that there are a lot of Hotels and Restaurants around the venue but there are not a lot of Gyms. The density of Hotels and Restaurants around the venue is also very good but the Gyms are quite scattered. Attention was directed towards the Hotels, Restaurants and Gyms that are located within the specified radius from the venue. Then, the location data was cleaned and organised. The missing values were dealt with and the useless data was dropped. Next, the Hotels, Restaurants and Gyms were sorted in ascdending order of their distance from the venue. After that, the required number of Hotels, Restaurants and Gyms were selected. Finally, these selected locations of interest were visualized on a map centered around the venue. The map shows the venue in a red dot, 8 Hotels as blue dots, 8 Restaurants as green dots and 3 Gyms as black dots.
#
# ## Conclusion <a name="conclusion"></a>
# The purpose of this project was to identify 8 nearest Hotels within 1.5 kilometers, 8 nearest Restaurants within 500 metres and 3 nearest Gyms within 3 kilometers of Flushing, NY 11368, United States. This project was undertaken in order to aid the management of USTA in finding suitable Hotels, Restaurants and Gyms to collaborate with. By using location data for Hotels, Restaurants and Gyms from Foursquare, the locations were identified, sorted and selected based on the requirements put forward by the management.
#
# The final decision on the suitable Hotels, Restaurants and Gyms for collaboration will be made by the management based on specific characteristics of each location, taking into consideration additional factors like facilities offered, affordability, reputation, approach from the venue, connectivity from the major parts of the city, criminal records, administration, etc.
